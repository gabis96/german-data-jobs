# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd

# %%
data = pd.read_parquet("../data/processed/linkedin_jobs_2023-02-02.parquet.gzip")
data
# Out:
#                                                   Title  \
# 0                       (Junior) Data Scientist (m/w/d)
# 1                        (Junior) Data Engineer (m/w/d)
# 2                                  Data Analyst (f/m/x)
# 3                                  Data Analyst (M/W/D)
# 4     Working Student Data Science and Data Engineer...
# ...                                                 ...
# 2008                              Director IT & Digital
# 2009                               Data Analyst (m/w/d)
# 2010                              Data Engineer (m/w/d)
# 2011  Analyst/Associate - Impact Data and Analysis (...
# 2012                              Director IT & Digital
#
#                               Company              Location  \
# 0                          VisualVest     Frankfurt am Main
# 1           Positive Thinking Company                  Köln
# 2                      Bonial Germany                Berlin
# ...

# %% [markdown]
# ### Fields
# - Title
# - Company
# - Seniority
# - Location (City): check veridity of the city
# - State: map state
# - Text
#
# **From text**
# - Employment Type: headline (full time, part time, internship)
# - Carrer level: headline
# - Salary
# - Keywords => to find most repited keywords accross posts

# %%
#
